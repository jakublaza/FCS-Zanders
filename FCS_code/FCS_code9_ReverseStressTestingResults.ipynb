# %% [markdown]
# # 6. STRESS TESTING

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy  as np
import warnings

# %%
warnings.filterwarnings('ignore')
plt.style.use('seaborn-whitegrid')

# %%
from utils import get_train_test, load_statistical_clusters, run_model, stress_test

# %% [markdown]
# ## From now on we use the dataset with imputed missing values

# %%
df = pd.read_csv('imputed_MICE_forrest.csv').iloc[:, 1:]

# %% [markdown]
# ## Merge the imputed dataset with info columns (first 8 columns from the orig dataset)
# * note: the number of observations in both df is the same and at the exact same order, so we can concat 1:1 withou using any merging key

# %%
data = pd.read_pickle('Erasmus_data_stresstesting_2024.pickle').iloc[:, 2:20]

countries_of_interest = ['FI', 'NL', 'AT', 'BE', 'SE', 'DE', 'NO', 'DK', 'IS', 'IT', 'ES', 'PT', 'LV', 'RO', 'HR', 'LT', 'BG', 'SK', 'CZ', 'SI', 'HU', 'PL']

subset_df = data[data['country_code'].isin(countries_of_interest)]

# %%
info = subset_df.iloc[:, :7]
info = info.reset_index().iloc[:, 1:]

# %%
df = pd.concat([info, df], axis = 1)

# %% [markdown]
# ## Now we obtain the macro and micro varibales and merge it with our latest df
# * note: this time macros are merged based on key:*country code* and WoE_country and WoE_industry on keys:*country_code* and *industry_code*

# %%
df2 = pd.read_csv('full_data_woe_rid_-2.csv').iloc[:, 2:]
macro = df2.iloc[:, 61:]

# %%
macro = pd.concat([df2[['country_code', 'status_year']], macro], axis = 1)

# %%
woe = df2[['country_code', 'industry_code', 'WoE_country', 'WoE_industry']]

# %%
macro_uni = macro.drop_duplicates()

# %%
woe_uni = woe.drop_duplicates()

# %%
df_new = pd.merge(df, woe_uni, on = ['country_code', 'industry_code'])
df_new = pd.merge(df_new, macro_uni, on = ['country_code', 'status_year'])

# %% [markdown]
# ## Variable *df_new* is final dataframe with info columns, firm characteristics, WoE columns and macro variables

# %%
df_new
# Out:
#         country_code industry_code size_class  status_year  \
# 0                 DE             G        SME         2020
# 1                 DE             G        SME         2020
# 2                 DE             G        SME         2020
# 3                 DE             G        SME         2020
# 4                 DE             G        SME         2020
# ...              ...           ...        ...          ...
# 1075921           LV             L        SME         2004
# 1075922           LV             J        SME         2004
# 1075923           LV             R        SME         2004
# 1075924           LV             A        SME         2001
# 1075925           IS            GX        SME         2002
#
#          status_date_latest status_latest  default_indicator  \
# 0                  16991231   non_default                  0
# 1                  16991231   non_default                  0
# 2                  16991231   non_default                  0
# 3                  16991231   non_default                  0
# 4                  16991231   non_default                  0
# ...                     ...           ...                ...
# 1075921            16991231   non_default                  0
# 1075922            16991231   non_default                  0
# 1075923            16991231   non_default                  0
# 1075924            16991231   non_default                  0
# 1075925            16991231   non_default                  0
#
#          intangible_fixed_assets_0  intangible_fixed_assets_1  \
# 0                           2905.0                9624.000000
# 1                              1.0                   1.000000
# 2                            310.0                   0.000000
# 3                           3269.0                3714.000000
# 4                             68.0                 262.000000
# ...                            ...                        ...
# 1075921                    66871.0               90739.000000
# 1075922                    19037.0               47858.105616
# 1075923                     5228.0               47858.105616
# 1075924                        0.0               47858.105616
# 1075925                        0.0               47858.105616
#
#          tangible_fixed_assets_0  ...  EURxTRY    hh_debt   corp_debt  \
# 0                        65007.0  ...  9.07982  57.055937  119.453344
# 1                       266426.0  ...  9.07982  57.055937  119.453344
# 2                       596041.0  ...  9.07982  57.055937  119.453344
# 3                       167798.0  ...  9.07982  57.055937  119.453344
# 4                      1053093.0  ...  9.07982  57.055937  119.453344
# ...                          ...  ...      ...        ...         ...
# 1075921                1936418.0  ...  1.82091  19.996895   88.332385
# 1075922                 203540.0  ...  1.82091  19.996895   88.332385
# 1075923                2498256.0  ...  1.82091  19.996895   88.332385
# 1075924                2271159.0  ...  1.29230   7.683075   83.443015
# 1075925               38969348.0  ...  1.73590  98.859518  322.509761
#
#          govt_debt  3m_yield  10y_yield     oil        gas     gold     copper
# 0        67.986011 -0.425150  -0.511024   32.84     3.4902  1898.36  6352.5562
# 1        67.986011 -0.425150  -0.511024   32.84     3.4902  1898.36  6352.5562
# 2        67.986011 -0.425150  -0.511024   32.84     3.4902  1898.36  6352.5562
# 3        67.986011 -0.425150  -0.511024   32.84     3.4902  1898.36  6352.5562
# 4        67.986011 -0.425150  -0.511024   32.84     3.4902  1898.36  6352.5562
# ...            ...       ...        ...     ...        ...      ...        ...
# 1075921  13.744445  4.231875   3.875000  234.51   692.6744   438.45  2323.6943
# 1075922  13.744445  4.231875   3.875000  234.51   692.6744   438.45  2323.6943
# 1075923  13.744445  4.231875   3.875000  234.51   692.6744   438.45  2323.6943
# 1075924  17.459588  6.861667   5.408333  114.44   990.0938   278.95  1678.1713
# 1075925  82.159950  8.974333   5.231833  152.93  1232.0769   348.05  1485.1486
#
# [1075926 rows x 80 columns]

# %% [markdown]
# ## In this step we assable the clusters based on statistical anlysis done in FCS_code2.5_Clustering.ipynb

# %%
clusters = load_statistical_clusters(df_new)

# %%
test = pd.read_csv('full_stress_data_base.csv').iloc[:, 1:]
test2 = pd.read_csv('full_stress_data-2.csv').iloc[:, 1:]
testD = pd.read_csv('DynamicLogitStress.csv').iloc[:, 2:].drop(['size_class'], axis = 1)

# %% [markdown]
# # Reverse Stress Testing

# %% [markdown]
# # War Scenario

# %% [markdown]
# We model the case if larger military conflict would happen in Europe. In this case we expect that government debt would skyrocet as Europe countries would have to found the war, at the same time, we would see a spike in inflation and gdp grotwh would plummet. Short terms would increase as well.

# %%
df_new.iloc[:, 58:].columns
# Out:
# Index(['WoE_country', 'WoE_industry', 'gdp_growth', 'inflation_growth',
#        'unemployment', 'EURxUSD', 'EURxJPY', 'EURxCNY', 'EURxINR', 'EURxGBP',
#        'EURxNOK', 'EURxCHF', 'EURxTRY', 'hh_debt', 'corp_debt', 'govt_debt',
#        '3m_yield', '10y_yield', 'oil', 'gas', 'gold', 'copper'],
#       dtype='object')

# %% [markdown]
# ### Stressing Variables

# %%
govt = test2[['country_code', 'status_year', 'govt_debt']]
govt_df = govt.drop_duplicates().sort_values('country_code')
govt_growth = {2023 : 1.2, 2024 : 1.25, 2025 : 1.3}
govt_df['govt_stressed'] = govt_df.apply(lambda row: row['govt_debt'] * govt_growth.get(row['status_year'], 1), axis=1)

# %%
pi = test2[['country_code', 'status_year', 'inflation_growth']]
pi_df = pi.drop_duplicates().sort_values('country_code')
pi_growth = {2023 : 1.1, 2024 : 1.2, 2025 : 1.25}
pi_df['pi_stressed'] = pi_df.apply(lambda row: row['inflation_growth'] * pi_growth.get(row['status_year'], 1), axis=1)

# %%
gdp = test2[['country_code', 'status_year', 'gdp_growth']]
gdp_df = gdp.drop_duplicates().sort_values('country_code')
gdp_growth = {2023 : 1.05, 2024 : 1.1, 2025 : 1.2}
gdp_df['gdp_stressed'] = gdp_df.apply(lambda row: row['gdp_growth'] * gdp_growth.get(row['status_year'], 1), axis=1)

# %%
m3 = test2[['country_code', 'status_year', '3m_yield']]
m3_df = m3.drop_duplicates().sort_values('country_code')
m3_growth = {2023 : 1.1, 2024 : 1.2, 2025 : 1.3}
m3_df['3m_stressed'] = m3_df.apply(lambda row: row['3m_yield'] * m3_growth.get(row['status_year'], 1), axis=1)

# %%
oil = test2[['country_code', 'status_year', 'oil']]
oil_df = oil.drop_duplicates().sort_values('country_code')
oil_growth = {2023 : 1.8, 2024 : 1.5, 2025 : 1.45}
oil_df['oil_stressed'] = oil_df.apply(lambda row: row['oil'] * oil_growth.get(row['status_year'], 1), axis=1)

# %%
gas = test2[['country_code', 'status_year', 'gas']]
gas_df = gas.drop_duplicates().sort_values('country_code')
gas_growth = {2023 : 1.8, 2024 : 1.5, 2025 : 1.45}
gas_df['gas_stressed'] = gas_df.apply(lambda row: row['gas'] * gas_growth.get(row['status_year'], 1), axis=1)

# %%
test_RVT = test

# %%
test_RVT = test_RVT.merge(gdp_df[['country_code', 'status_year', 'gdp_stressed']], on = ['country_code', 'status_year'])

# %%
test_RVT = test_RVT.merge(pi_df[['country_code', 'status_year', 'pi_stressed']], on = ['country_code', 'status_year'])

# %%
test_RVT = test_RVT.merge(govt_df[['country_code', 'status_year', 'govt_stressed']], on = ['country_code', 'status_year'])

# %%
test_RVT = test_RVT.merge(m3_df[['country_code', 'status_year', '3m_stressed']], on = ['country_code', 'status_year'])

# %%
test_RVT = test_RVT.merge(oil_df[['country_code', 'status_year', 'oil_stressed']], on = ['country_code', 'status_year'])

# %%
test_RVT = test_RVT.merge(gas_df[['country_code', 'status_year', 'gas_stressed']], on = ['country_code', 'status_year'])

# %%
test_RVT['govt_debt'] = test_RVT['govt_stressed']

# %%
test_RVT['gdp_growth'] = test_RVT['gdp_stressed']

# %%
test_RVT['inflation_growth'] = test_RVT['pi_stressed']

# %%
test_RVT['3m_yield'] = test_RVT['3m_stressed']

# %%
test_RVT['oil'] = test_RVT['oil_stressed']

# %%
test_RVT['gas'] = test_RVT['gas_stressed']

# %%
test_RVT = test_RVT.iloc[:, :-6]

# %%
test_RVT
# Out:
#        country_code industry_code  status_year  status_date_latest  \
# 0                DE             G         2023            20160401
# 1                DE             G         2023            20181030
# 2                DE             G         2023            16991231
# 3                DE             G         2023            16991231
# 4                DE             G         2023            20160825
# ...             ...           ...          ...                 ...
# 178879           LV             B         2025            16991231
# 178880           LV             S         2025            20150408
# 178881           LV             S         2025            16991231
# 178882           LV             S         2025            16991231
# 178883           LV             S         2025            16991231
#
#        status_latest  default_indicator  intangible_fixed_assets_0  \
# 0        non_default                  0                        1.0
# 1        non_default                  0                    96855.0
# 2        non_default                  0                      932.0
# 3        non_default                  0                        5.0
# 4        non_default                  0                    21127.0
# ...              ...                ...                        ...
# 178879   non_default                  0                      320.0
# 178880   non_default                  0                        0.0
# 178881   non_default                  0                      479.0
# 178882   non_default                  0                   358049.0
# 178883   non_default                  0                        0.0
#
#         intangible_fixed_assets_1  tangible_fixed_assets_0  \
# 0                        1.000000                  77347.0
# 1                   127632.000000                 285802.0
# 2                   854302.483872                2139690.0
# 3                        5.000000                 272832.0
# 4                   928298.200777                  99691.0
# ...                           ...                      ...
# 178879              931967.301693                 178057.0
# 178880                   0.000000                 686745.0
# 178881              788296.194708                1306865.0
# 178882              207365.000000                4862823.0
# 178883              952443.728354                 346823.0
#
#         tangible_fixed_assets_1  ...  EURxTRY    hh_debt   corp_debt  \
# 0                  9.290600e+04  ...    17.15  59.547265  111.313833
# 1                  3.118150e+05  ...    17.15  59.547265  111.313833
# 2                  3.044565e+06  ...    17.15  59.547265  111.313833
# 3                  3.075800e+05  ...    17.15  59.547265  111.313833
# 4                  1.573224e+06  ...    17.15  59.547265  111.313833
# ...                         ...  ...      ...        ...         ...
# 178879             9.332394e+05  ...    17.15   8.127991    8.582985
# 178880             7.517590e+05  ...    17.15   8.127991    8.582985
# 178881             2.056950e+06  ...    17.15   8.127991    8.582985
# 178882             4.452594e+06  ...    17.15   8.127991    8.582985
# 178883             1.785393e+06  ...    17.15   8.127991    8.582985
#
#         govt_debt  3m_yield  10y_yield         oil          gas     gold  \
# 0       90.008511    0.4653       1.99  370.911713  2426.710477  1070.87
# 1       90.008511    0.4653       1.99  370.911713  2426.710477  1070.87
# 2       90.008511    0.4653       1.99  370.911713  2426.710477  1070.87
# 3       90.008511    0.4653       1.99  370.911713  2426.710477  1070.87
# 4       90.008511    0.4653       1.99  370.911713  2426.710477  1070.87
# ...           ...       ...        ...         ...          ...      ...
# 178879  49.273954    0.7280       3.65  274.521798  1954.850106  1070.87
# 178880  49.273954    0.7280       3.65  274.521798  1954.850106  1070.87
# 178881  49.273954    0.7280       3.65  274.521798  1954.850106  1070.87
# 178882  49.273954    0.7280       3.65  274.521798  1954.850106  1070.87
# 178883  49.273954    0.7280       3.65  274.521798  1954.850106  1070.87
#
#          copper
# 0       4709.59
# 1       4709.59
# 2       4709.59
# 3       4709.59
# 4       4709.59
# ...         ...
# 178879  4709.59
# 178880  4709.59
# 178881  4709.59
# 178882  4709.59
# 178883  4709.59
#
# [178884 rows x 77 columns]

# %% [markdown]
# ### Results

# %%
T_clusters = load_statistical_clusters(test_RVT) # already withou WOE
T_clusters2 = load_statistical_clusters(test2) # with WOE

# %%
for cluster in range(len(clusters)):
        y = clusters[cluster]['default_indicator']
        X = clusters[cluster].iloc[:, 7:].drop(['WoE_country', 'WoE_industry'], axis=1)
        data = get_train_test(X, y, use_SMOTE=True)
        m = run_model(data, type = 'RF', n_estimators=50, max_depth=3)
        print(f'Cluster {cluster + 1}')
        prob = stress_test(m, T_clusters[cluster], X, y)
        prob = stress_test(m, T_clusters2[cluster].drop(['WoE_country', 'WoE_industry'], axis=1), X, y)
# Out:
# Results for RF
# ------------------------------
# Confussion Matrx:
#  [[70510  1839]
#  [  211   317]]
#
# AUC: 0.9039
#
# Feature Importance:
#
# ==============================
# Cluster 1
# Total default rate over 3 years: 2.399
# Default Rate in the train data: 0.0072451239492512
# Stress Test increased PD by multiple of 3.3105510167281604
# Number of defaults:
# Year 2023 : 393
# Year 2024 : 0
# Year 2025 : 0
# Total default rate over 3 years: 2.386
# Default Rate in the train data: 0.0072451239492512
# Stress Test increased PD by multiple of 3.2937034288567704
# Number of defaults:
# Year 2023 : 391
# Year 2024 : 0
# Year 2025 : 0
# Results for RF
# ------------------------------
# Confussion Matrx:
#  [[9023  132]
#  [  28   14]]
#
# AUC: 0.8669
#
# Feature Importance:
#
# ==============================
# Cluster 2
# Total default rate over 3 years: 0.714
# Default Rate in the train data: 0.004523410825739947
# Stress Test increased PD by multiple of 1.5782812929039345
# Number of defaults:
# Year 2023 : 12
# Year 2024 : 0
# Year 2025 : 2
# Total default rate over 3 years: 0.51
# Default Rate in the train data: 0.004523410825739947
# Stress Test increased PD by multiple of 1.1273437806456674
# Number of defaults:
# Year 2023 : 10
# Year 2024 : 0
# Year 2025 : 0
# Results for RF
# ------------------------------
# Confussion Matrx:
#  [[22868   385]
#  [  159    96]]
#
# AUC: 0.8852
#
# Feature Importance:
#
# ==============================
# Cluster 3
# Total default rate over 3 years: 0.629
# Default Rate in the train data: 0.010856248298393684
# Stress Test increased PD by multiple of 0.5790911443118801
# Number of defaults:
# Year 2023 : 30
# Year 2024 : 0
# Year 2025 : 1
# Total default rate over 3 years: 0.264
# Default Rate in the train data: 0.010856248298393684
# Stress Test increased PD by multiple of 0.24284467342111102
# Number of defaults:
# Year 2023 : 13
# Year 2024 : 0
# Year 2025 : 0
# Results for RF
# ------------------------------
# Confussion Matrx:
#  [[13360    12]
#  [   82     1]]
#
# AUC: 0.7731
#
# Feature Importance:
#
# ==============================
# Cluster 4
# Total default rate over 3 years: 0.0
# Default Rate in the train data: 0.006169077314147255
# Stress Test increased PD by multiple of 0.0
# Number of defaults:
# Year 2023 : 0
# Year 2024 : 0
# Year 2025 : 0
# Total default rate over 3 years: 0.0
# Default Rate in the train data: 0.006169077314147255
# Stress Test increased PD by multiple of 0.0
# Number of defaults:
# Year 2023 : 0
# Year 2024 : 0
# Year 2025 : 0
# Results for RF
# ------------------------------
# Confussion Matrx:
#  [[6430   13]
#  [  23    2]]
#
# AUC: 0.7749
#
# Feature Importance:
#
# ==============================
# Cluster 5
# Total default rate over 3 years: 0.187
# Default Rate in the train data: 0.0038654214855587854
# Stress Test increased PD by multiple of 0.4833781763826607
# Number of defaults:
# Year 2023 : 5
# Year 2024 : 0
# Year 2025 : 0
# Total default rate over 3 years: 0.0
# Default Rate in the train data: 0.0038654214855587854
# Stress Test increased PD by multiple of 0.0
# Number of defaults:
# Year 2023 : 0
# Year 2024 : 0
# Year 2025 : 0
# Results for RF
# ------------------------------
# Confussion Matrx:
#  [[4507   42]
#  [  10    1]]
#
# AUC: 0.7924
#
# Feature Importance:
#
# ==============================
# Cluster 6
# Total default rate over 3 years: 0.274
# Default Rate in the train data: 0.0024127039831549394
# Stress Test increased PD by multiple of 1.1374114359844327
# Number of defaults:
# Year 2023 : 5
# Year 2024 : 0
# Year 2025 : 0
# Total default rate over 3 years: 0.274
# Default Rate in the train data: 0.0024127039831549394
# Stress Test increased PD by multiple of 1.1374114359844327
# Number of defaults:
# Year 2023 : 5
# Year 2024 : 0
# Year 2025 : 0
# Results for RF
# ------------------------------
# Confussion Matrx:
#  [[31953   196]
#  [  104    21]]
#
# AUC: 0.762
#
# Feature Importance:
#
# ==============================
# Cluster 7
# Total default rate over 3 years: 0.816
# Default Rate in the train data: 0.0038669616464332857
# Stress Test increased PD by multiple of 2.108944230934316
# Number of defaults:
# Year 2023 : 95
# Year 2024 : 0
# Year 2025 : 0
# Total default rate over 3 years: 0.163
# Default Rate in the train data: 0.0038669616464332857
# Stress Test increased PD by multiple of 0.42178884618686313
# Number of defaults:
# Year 2023 : 19
# Year 2024 : 0
# Year 2025 : 0
# Results for RF
# ------------------------------
# Confussion Matrx:
#  [[30672   288]
#  [  147    27]]
#
# AUC: 0.7389
#
# Feature Importance:
#
# ==============================
# Cluster 8
# Total default rate over 3 years: 0.0
# Default Rate in the train data: 0.005595277097907713
# Stress Test increased PD by multiple of 0.0
# Number of defaults:
# Year 2023 : 0
# Year 2024 : 0
# Year 2025 : 0
# Total default rate over 3 years: 0.0
# Default Rate in the train data: 0.005595277097907713
# Stress Test increased PD by multiple of 0.0
# Number of defaults:
# Year 2023 : 0
# Year 2024 : 0
# Year 2025 : 0
# Results for RF
# ------------------------------
# Confussion Matrx:
#  [[5193   56]
#  [  17    0]]
#
# AUC: 0.6026
#
# Feature Importance:
#
# ==============================
# Cluster 9
# Total default rate over 3 years: 0.347
# Default Rate in the train data: 0.003304341220707205
# Stress Test increased PD by multiple of 1.0515364277555455
# Number of defaults:
# Year 2023 : 5
# Year 2024 : 0
# Year 2025 : 0
# Total default rate over 3 years: 0.139
# Default Rate in the train data: 0.003304341220707205
# Stress Test increased PD by multiple of 0.42061457110221817
# Number of defaults:
# Year 2023 : 2
# Year 2024 : 0
# Year 2025 : 0
# Results for RF
# ------------------------------
# Confussion Matrx:
#  [[16354    10]
#  [   88     0]]
#
# AUC: 0.7921
#
# Feature Importance:
#
# ==============================
# Cluster 10
# Total default rate over 3 years: 0.261
# Default Rate in the train data: 0.005349153861116515
# Stress Test increased PD by multiple of 0.4880102227090179
# Number of defaults:
# Year 2023 : 13
# Year 2024 : 0
# Year 2025 : 0
# Total default rate over 3 years: 0.02
# Default Rate in the train data: 0.005349153861116515
# Stress Test increased PD by multiple of 0.037539247900693684
# Number of defaults:
# Year 2023 : 1
# Year 2024 : 0
# Year 2025 : 0
